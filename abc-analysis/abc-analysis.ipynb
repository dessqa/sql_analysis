# %%
import pandas as pd
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('abc-analysis.csv')

# %%
data
# Out:
#         productLine  sum_profit    percent  total cat_ABC
# 0      Classic Cars  3853922.49  40.127509     40       A
# 1      Vintage Cars  1797559.63  18.716409     59       A
# 2       Motorcycles  1121426.12  11.676425     71       A
# 3  Trucks and Buses  1024113.57  10.663195     81       B
# 4            Planes   954637.54   9.939802     91       B
# 5             Ships   663998.34   6.913631     98       C
# 6            Trains   188532.92   1.963028    100       C

# %%
import numpy as np

# %%
sns.set(font_scale=2)
plt.pie(x=data.percent, explode=[.3, .3, .3, .15, .15, 0, 0],
labels=data.productLine, radius=2)
# Out:
# ([<matplotlib.patches.Wedge at 0x1af828adcd0>,
#   <matplotlib.patches.Wedge at 0x1af828bb1f0>,
#   <matplotlib.patches.Wedge at 0x1af828bb6d0>,
#   <matplotlib.patches.Wedge at 0x1af828bbbb0>,
#   <matplotlib.patches.Wedge at 0x1af828c70d0>,
#   <matplotlib.patches.Wedge at 0x1af828c75b0>,
#   <matplotlib.patches.Wedge at 0x1af828c7a90>],
#  [Text(0.7630116406585777, 2.3807169584432977, 'Classic Cars'),
#   Text(-2.4986949299181935, 0.08076909805805896, 'Vintage Cars'),
#   Text(-1.509561418848828, -1.9927930958137912, 'Motorcycles'),
#   Text(0.12573421907487256, -2.346633952314172, 'Trucks and Buses'),
#   Text(1.515334223852179, -1.796179887990709, 'Planes'),
#   Text(2.073665042109981, -0.7347879239147939, 'Ships'),
#   Text(2.1958178454120163, -0.13558757232922228, 'Trains')])

# %%
fig1, ax1 = plt.subplots()
ax1.pie(data.percent, explode=[.3, .3, .3, .15, .15, 0, 0], labels=data.productLine, autopct='%1.1f%%',
        shadow=True, startangle=90, radius=3)
plt.show()
