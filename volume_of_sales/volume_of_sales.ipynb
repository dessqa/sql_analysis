# %%
import seaborn as sns
import pandas as pd

# %%
data = pd.read_csv('volume_of_sales.csv', header=0, sep=",")

# %%
data
# Out:
#        Статус  Денежный оборот  \
# 0     Shipped       8865094.64
# 1   Cancelled        238854.18
# 2     On Hold        169575.61
# 3  In Process        135271.52
# 4    Resolved        134235.88
# 5    Disputed         61158.78
#
#    Процентное соотношение прибыли/затрат на общую потенциальную прибыль
# 0                                          92.304443
# 1                                           2.486979
# 2                                           1.765642
# 3                                           1.408464
# 4                                           1.397680
# 5                                           0.636793

# %%
new_col = ["Status", "Money", "Percent"]
data.columns = new_col

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = data.Status
sizes = data.Percent

sns.set(font_scale=2)
sns.catplot(x="Money", y="Percent", hue="Status", kind="bar", 
data=data , height=6, aspect=2,dodge=False)
